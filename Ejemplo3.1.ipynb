# %%
import Motoresdecombustioninterna as th

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
p1 = 150 # psi
t1 = 800 # °R
v1 = 0
p2 = 80 # psi
u = 1 # UNIDADES INGLESAS
R = 35.133 # ft*lbf/(lbm*°R)

# %% [markdown]
# Calcular p_th, t_th y v_th si

# %%
#Dioxido de carbono
quim1 = "CO2"
#Nitrógeno
quim2 = "N2"

# %% [markdown]
# Conseguir valores de Dioxido de Carbono

# %%
M, Cpmol, Cp, k = th.valoresCompuestos(quim1,u)

# %% [markdown]
# Calcular la presión de ahogamiento

# %%
p_ah = p1*(2/(k+1))**(k/(k-1))
p_ah
# Out:
# 82.18585812907847

# %%
pth, tth, vth = th.verificarEstancado(p2,p_ah,t1,k,p1,Cp,u)
# Out:
# Estancado
# Los valores entregados son
# Pth, Tth, Vth

# %%
print("La presion en la garganta es", pth)
# Out:
# La presion en la garganta es 82.18585812907847

# %%
print("La temperatura en la garganta es",tth)
# Out:
# La temperatura en la garganta es 699.3006993006992

# %%
print("La velocidad en la garganta es",vth)
# Out:
# La velocidad en la garganta es 1009.0206616970082

# %% [markdown]
# Conseguir valores de nitrógeno

# %%
M2,Cpmol2,Cp2,k2 = th.valoresCompuestos(quim2,u)

# %% [markdown]
# Calcular presión de ahogamiento

# %%
p_ah2 = p1*(2/(k2+1))**(k2/(k2-1))
p_ah2
# Out:
# 79.26754118570032

# %%
pthN,tthN,vthN = th.verificarEstancado(pd= p2, pahogamiento=p_ah1, tent=t1, k=k, p1=p1, cp=Cp, u=u)
# Out:
# No estancado
# Los valores entregados son
# Pth, Tth, Vth

# %%
pthN
# Out:
# 80

# %%
tthN
# Out:
# 668.6964374698773

# %%
vthN
# Out:
# 1278.19555481791
